# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmiAhala/MachineLearning/blob/main/ML_Assign4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the above manner, I added data for 2 other colours - Yellow and Black

# %% [markdown]
# # My model predicting the colour Black
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # My model predicting the colour Yellow
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1) What did you create?**
#
# I created a model that can identify the three colours - Yellow, Black, and Pink. When you hold up an object with one of these colours, it will identify it.
#
# **2) How accurate is your model?**
#
# My model is quite accurate actually. It can identify even a small portion of the colour in the frame. If you give a colour that is not Pink, Yellow, or Black it will see the closest match and identify.
#
# For example, when I covered my face with my hand, it said 60% black and 40% yellow (approx) because of the shadows.
#
# **3) Training Data matters**
#
# I trained my final model with around 140 examples.
# In the start when I had only around 40, it would get a bit confused. But, now that I have more, I feel like the model has more clarity and can choose from a wider range of data.
#
# **4) Real-World Connection**
#
# -- Sorting coloured objects in recycle plants (Sorting)
# -- Identifying ripeness of fruits (Agriculture)
# -- Tagging clothing colours for online retail (Fashion Designing)
# -- Detection of colour changes in chemical reactions (Chemistry)
# -- Teaching colour concepts (Art)
