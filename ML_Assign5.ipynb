# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmiAhala/MachineLearning/blob/main/ML_Assign5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# Setting display options
pd.set_option('display.max_columns', None)
# %matplotlib inline

print("✓ Libraries imported successfully!")
# Out:
# ✓ Libraries imported successfully!

# %% [markdown]
# #Part1: SETUP AND EXAMPLE

# %%
#@title 1.1: Loading Iris Dataset

# Step 1: Loading the dataset
iris = datasets.load_iris()
print("Dataype of iris: ", type(iris))

# Step 2: Understanding the dataset structure
print("📦 Dataset Components:")
print(f"   - data: Features (measurements)")
print(f"   - target: Labels (species)")
print(f"   - feature_names: Column names for features")
print(f"   - target_names: Names of species")
print(f"   - DESCR: Dataset description\n")

# Step 3: Creating DataFrame from features
df_iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)
print("dataype of df_iris: ", type(df_iris))

# Step 4: Adding the target column
df_iris['species'] = iris.target

# Step 5: Replacing numeric df_iris with actual names
df_iris['species_name'] = df_iris['species'].map({
    0: iris.target_names[0],
    1: iris.target_names[1],
    2: iris.target_names[2]
})

print("✅ iris Dataset loaded successfully!")
print(f"\nDataFrame shape: {df_iris.shape}")
print(f"Columns: {list(df_iris.columns)}")

# Displaying the first few rows
print("🔍 First 5 rows of Iris dataset:\n")
display(df_iris.head())

print("\n📊 Basic Information:")
df_iris.info()
# Out:
# Dataype of iris:  <class 'sklearn.utils._bunch.Bunch'>
# 📦 Dataset Components:
#    - data: Features (measurements)
#    - target: Labels (species)
#    - feature_names: Column names for features
#    - target_names: Names of species
#    - DESCR: Dataset description
#
# dataype of df_iris:  <class 'pandas.core.frame.DataFrame'>
# ✅ iris Dataset loaded successfully!
#
# DataFrame shape: (150, 6)
# Columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'species', 'species_name']
# 🔍 First 5 rows of Iris dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# ...

# %%
#@title 1.2: Read the Dataset Description

descr = iris.DESCR
print(descr)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %% [markdown]
# ## Iris Dataset Questions
#
# Q1) How many samples (rows) are in the Iris dataset?- 150
#
# Q2) How many features (measurements) are there?- 4
#
# Q3) What are the three species of Iris flowers?- Setos, Versicolour, and Virginica
#
# Q4) What do the four features measure?- Sepal Length, Sepal Width, Petal Length, Petal Width (all in cm)

# %% [markdown]
# #Part2: WINE DATASET EXPLORATION

# %%
#@title 2.1: Loading Wine Dataset

# Step 1: Loading the wine dataset
wine = datasets.load_wine()

# Step 2: Creating a DataFrame with the features
df_wine = pd.DataFrame(data=wine.data, columns=wine.feature_names)
print("Dataype of df_wine: ", type(df_wine))

# Step 3: Add the target column
df_wine['target'] = wine.target

# Step 4: Adding target names
mapped_names = [wine.target_names[t] for t in wine.target]

print("✅ Wine dataset loaded!")
print(f"Shape: {df_wine.shape}")
# Out:
# Dataype of df_wine:  <class 'pandas.core.frame.DataFrame'>
# ✅ Wine dataset loaded!
# Shape: (178, 14)

# %%
#@title 2.2: Basic Exploration

# Displaying the first 10 rows
print("First 10 rows of Wine dataset:")
display(df_wine.head(10))

# Displaying the last 5 rows
print("\nLast 5 rows of Wine dataset:")
display(df_wine.tail(5))

# Displaying random 5 rows
print("\n5 random rows of Wine dataset:")
display(df_wine.sample(5))

# Displaying basic information about the dataset
print("\nBasic information about the dataset:")
display(df_wine.info())

# Displaying statistical summary
print("\nStatistical Summary:")
display(df_wine.describe())

# Checking for missing values
print("\nChecking for missing values:")
display(df_wine.isna().sum())
# Out:
# First 10 rows of Wine dataset:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# ...

# %% [markdown]
# ## Wine Dataset Questions
#
# Q1) How many wine samples are in the dataset?- 178
#
# Q2) How many features (chemical measurements) are there?- 13
#
# Q3) What is the average (mean) alcohol content?- ~13
#
# Q4) Are there any missing values in the dataset?- 0
#
# Q5) What is the maximum value of 'proline'?- 1680

# %% [markdown]
# #Part3: BREAST CANCER DATASET EXPLORATION

# %%
#@title 3.1: Loading Breast Cancer Dataset

# Step 1: Loading the breast cancer dataset
bc = datasets.load_breast_cancer()

# Step 2: Creating a DataFrame with the features
df_bc = pd.DataFrame(data=bc.data, columns=bc.feature_names)
print("Dataype of df_bc: ", type(df_bc))

# Step 3: Add the target column
df_bc['target'] = bc.target

# Step 4: Adding target names
mapped_names = [bc.target_names[t] for t in bc.target]

print("✅ Breast Cancer dataset loaded!")
# Out:
# Dataype of df_bc:  <class 'pandas.core.frame.DataFrame'>
# ✅ Breast Cancer dataset loaded!

# %%
#@title 3.2: Comprehensive EDA

# Displaying dataset shape
print(f"Shape: {df_bc.shape}")

# Displaying first 5 rows
print("\nFirst 5 rows of Wine dataset:")
display(df_bc.head(5))

# Displaying column names
print("\nColoumn Names:")
display(df_bc.columns)

# Displaying data types of all columns
print("\nData types of all coloumns:")
display(df_bc.dtypes)

# Displaying statistical summary
print("\nStatistical Summary:")
display(df_bc.describe())

# Displaying how many samples are in each class
df_bc['target'] = bc.target
print("\nNo. of samples in each class: ")
print(df_bc['target'].value_counts())
# Out:
# Shape: (569, 31)
#
# First 5 rows of Wine dataset:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
# ...

# %%
#@title 3.3: Creating Visualizations

# Creating a bar plot showing the count of each class
print("Creating a bar plot showing the count of each class: ")
df_bc['target'].value_counts().plot(kind='bar')
plt.title('Distribution of Breast Cancer Classes')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# Creating a histogram of 'mean radius'
print("\nCreating a histogram of 'mean radius': ")
df_bc['mean radius'].hist()
plt.title('Distribution of Mean Radius')
plt.xlabel('Mean Radius')
plt.ylabel('Frequency')
plt.show()

# Creating a scatter plot of 'mean radius' vs 'mean texture'
print("\nCreating a scatter plot of 'mean radius' vs 'mean texture': ")
plt.scatter(df_bc['mean radius'], df_bc['mean texture'], c=df_bc['target'])
plt.title('Mean Radius vs Mean Texture')
plt.xlabel('Mean Radius')
plt.ylabel('Mean Texture')
plt.colorbar(label='Class (0=Malignant, 1=Benign)')
plt.show()
# Out:
# Creating a bar plot showing the count of each class:
# Creating a histogram of 'mean radius':
# Creating a scatter plot of 'mean radius' vs 'mean texture':

# %% [markdown]
# ## Breast Cancer Dataset Questions
#
# Q1) Total samples in the breast cancer dataset- 569
#
# Q2) Number of Features- 30
#
# Q3) Which class has more samples--> malignant or benign?- benign
#
# Q4) Mean value of 'mean radius'- 14.13
#
# Q5) Looking at your scatter plot, can you see any pattern that might help distinguish between malignant and benign cases?- Malignant cases tend to have larger mean radius and mean texture values compared to benign cases. There seems to be a separation between the two classes based on these two features, suggesting they could be useful for distinguishing between malignant and benign tumors.

# %% [markdown]
# #Reflection
#
# Q1) What was the most interesting thing you learned from exploring these datasets?- Iris is the simplest among the 3 with the least number of features while wine with 13 is quite balanced. Breast Cancer on the other hand is more of a real life example showing that how you represent data (and how much data) is as important as the data itself.
#
# Q2) Which dataset did you find most interesting and why?- I personally found the Breast Cancer dataset the most interesting as it is the closest to real world examples. The number of features and classes used to come to a diagnois is astonishing.
#
# Q3) How do you think machine learning could be used with the Breast Cancer dataset in real life?-
#
# --> Flagging suspicious cases for further checking
# --> Early Detection and screening
# --> Predict aggressiveness of tumor
# --> Prioritising cases
